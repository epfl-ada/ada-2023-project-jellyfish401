# %% [markdown]
# # Milestone 2
# Initial analysis and data handling pipeline for the project.
# The notebook is structured in the following way:
# - Loading data
# - Data wrangling
# - Data analysis for the research questions
#     - Regarding the articles structure
#         * Q1: How different are the length of these articles and their number of hyperlinks?
#         * Q2: How positive or negative is the content of an article and the articles linked to it?
#     - Regarding the pathways
#         * Q3: Is there a correlation between the ratio of finished pathways and the country?
#         * Q4: Is there a correlation between the length of the pathway taken respectively the time needed and the country?
#     - Regarding confounding variables
#         * Q5: By investigating article length, article sentiment or number of hyperlinks while controlling for e.g. population size, economic power or if English is an official language, is there a representation bias based on countries in Wikipedia?
#         * Q6: While controlling for as much of the bias in the dataset as we can, do we see additional bias of the players in the pathways they have taken?
#
#
#     To compare all countries (more than 200) would be too confusing, therefore they are grouped by region/continent and by economic developement.
#
#
# ## Loading data

# %%
# Loading all the necessary packages
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.offsetbox import AnchoredText
from urllib.parse import unquote
import seaborn as sns
import networkx as nx
#import plotly.express as px
#import plotly.graph_objects as go
import statsmodels.formula.api as smf
import scipy.stats as stats
from urllib.parse import unquote

# %%
articles =  pd.read_csv("data/wikispeedia_paths-and-graph/articles.tsv", sep='\t', names=["article"], skiprows=12)
links = pd.read_csv("data/wikispeedia_paths-and-graph/links.tsv", sep='\t', names=["link_source", "link_target"], skiprows = 12)
paths_finished = pd.read_csv("data/wikispeedia_paths-and-graph/paths_finished.tsv", sep='\t', names=["hashedIpAddress", "timestamp", 
                                                              "durationInSec", "path", "rating"], skiprows = 15)
paths_unfinished = pd.read_csv("data/wikispeedia_paths-and-graph/paths_unfinished.tsv", sep='\t', names=["hashedIpAddress", "timestamp", 
                                                                  "durationInSec", "path", "target", "type"], skiprows = 17)
shortest_distance_text = np.loadtxt("data/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt", dtype=str, comments="#", unpack=False)
categories= pd.read_csv("data/wikispeedia_paths-and-graph/categories.tsv", sep='\t', names=["article", "category"], skiprows = 13)

# seperate each row and create a matrix with all the shortest distance
table_distance = np.array([[int(c) if c != '_' else -1 for c in row] for row in shortest_distance_text])

UN_countries = pd.read_csv("data/UNSD — Methodology.csv", delimiter = ';')
UN_countries_by_economies_load = pd.read_csv("data/countries_by_income_category.csv")
UN_countries_by_economies_load.columns = ['Country or Area', 'Economic classification']

# %%
#print(UN_countries.head())

# %%
def seperate_path(path):
    # Split the path into individual articles
    articles = path.split(";")
    
    # Extract source and target
    source, target = articles[0], articles[-1]
    
    # Calculate the length, considering back-clicks
    length = len(articles) + articles.count('') - 1
    
    return source, target, length

# Find the index of an article in the helper DataFrame
def find_article_index(article, helper_df):
    try:
        return helper_df.loc[article]
    except KeyError:
        return None

# Calculate the shortest distance between source and target indices
def calculate_shortest_distance(source_idx, target_idx):
    try:
        return table_distance[source_idx, target_idx][0]
    except KeyError:
        return None

# Finding the shortest path length between a source and a target
def find_path_distance(source, target, helper_df):
    source_idx = find_article_index(source, helper_df)
    target_idx = find_article_index(target, helper_df)

    if source_idx is not None and target_idx is not None:
        return calculate_shortest_distance(source_idx, target_idx)
    else:
        # Handle the case where source or target is not present in the index
        return None

def extract_subject_category(category):
    # Split the category string by '.'
    category_parts = category.split('.')
    
    # Find the index of 'subject' in the split parts
    subject_index = category_parts.index('subject')
    
    # Check if there is at least one word after 'subject'
    if subject_index < len(category_parts) - 1:
        return category_parts[subject_index + 1]

# %% [markdown]
# ## Data wrangling
# We now parse and transform the data into appropriate data model and format that will be used for the analysis we want to do. For instance article titles are transformed to a readable format, paths are expanded so that we may build a dataframe that gives an overwiew of the paths.

# %%
# Translating all article titles to user readable format
articles['article'] = articles['article'].apply(unquote)
links['link_source'] = links['link_source'].apply(unquote)
links['link_target'] = links['link_target'].apply(unquote)
paths_finished['path'] = paths_finished['path'].apply(unquote)
paths_unfinished['path'] = paths_unfinished['path'].apply(unquote)
paths_unfinished['target'] = paths_unfinished['target'].apply(unquote)
categories['article'] = categories['article'].apply(unquote)

# %%
articles.head()
# Out:
#                  article
# 0      Áedán_mac_Gabráin
# 1                  Åland
# 2          Édouard_Manet
# 3                   Éire
# 4  Óengus_I_of_the_Picts

# %%
# expand the finished paths
path_fin = paths_finished.copy()
path_fin = path_fin.assign(source=paths_finished['path'].apply(lambda x: seperate_path(x)[0]),
                           target=paths_finished['path'].apply(lambda x: seperate_path(x)[1]),
                           game_path=paths_finished['path'].apply(lambda x: seperate_path(x)[2]),
                           completed=True)

# expand the unfinished paths
path_ufin = paths_unfinished.copy()
path_ufin = path_ufin.assign(source=paths_unfinished['path'].apply(lambda x: seperate_path(x)[0]),
                             failure_article=paths_unfinished['path'].apply(lambda x: seperate_path(x)[1]),
                             game_path=paths_unfinished['path'].apply(lambda x: seperate_path(x)[2]),
                             completed=False,
                             target=paths_unfinished["target"])

# construct a new dataframe: path_overview
path_overview = pd.concat([path_fin, path_ufin], ignore_index=True)[["source", "target",  "hashedIpAddress", "timestamp",
                                                                     "durationInSec", "game_path",
                                                                     "completed", "rating","type"]]
path_overview.head()
# Out:
#          source               target   hashedIpAddress   timestamp  \
# 0  14th_century  African_slave_trade  6a3701d319fc3754  1297740409
# 1  14th_century  African_slave_trade  3824310e536af032  1344753412
# 2  14th_century  African_slave_trade  415612e93584d30e  1349298640
# 3  14th_century               Greece  64dd5cd342e3780c  1265613925
# 4  14th_century      John_F._Kennedy  015245d773376aab  1366730828
#
#    durationInSec  game_path  completed  rating type
# 0            166          8       True     NaN  NaN
# 1             88          4       True     3.0  NaN
# 2            138          7       True     NaN  NaN
# 3             37          3       True     NaN  NaN
# 4            175          6       True     3.0  NaN

# %%
articles["index"] = articles.index
help_articles = articles.set_index("article")

# shortest path length is added to the path_overview
# Create a copy of the 'path_overview' DataFrame to avoid modifying the original
path_overview_copy = path_overview.copy()

# Apply the find_path_distance function to each row
path_overview_copy['shortest_distance'] = path_overview_copy.apply(
    lambda row: find_path_distance(row['source'], row['target'], help_articles), axis=1
)

# Update the original 'path_overview' DataFrame with the new 'shortest_distance' column
path_overview['shortest_distance'] = path_overview_copy['shortest_distance']

display(path_overview)
# Out:
#                      source               target   hashedIpAddress  \
# 0              14th_century  African_slave_trade  6a3701d319fc3754
# 1              14th_century  African_slave_trade  3824310e536af032
# 2              14th_century  African_slave_trade  415612e93584d30e
# 3              14th_century               Greece  64dd5cd342e3780c
# 4              14th_century      John_F._Kennedy  015245d773376aab
# ...                     ...                  ...               ...
# 76188           Franz_Kafka              Cholera  109ed71f571d86e9
# 76189        Modern_history            Hollandic  232f992e57d43e8d
# 76190  Computer_programming          The_Beatles  2e09a7224600a7cd
# 76191               Jamaica          Alan_Turing  60af9e2138051b96
# 76192           Mark_Antony              Feather  1cf0cbb3281049ab
#
#         timestamp  durationInSec  game_path  completed  rating     type  \
# 0      1297740409            166          8       True     NaN      NaN
# 1      1344753412             88          4       True     3.0      NaN
# 2      1349298640            138          7       True     NaN      NaN
# 3      1265613925             37          3       True     NaN      NaN
# 4      1366730828            175          6       True     3.0      NaN
# ...           ...            ...        ...        ...     ...      ...
# 76188  1389787605            180          7      False     NaN  restart
# 76189  1389787697              6          0      False     NaN  restart
# 76190  1389798400           1900          4      False     NaN  timeout
# 76191  1389799481           1903          3      False     NaN  timeout
# 76192  1389822841            352          4      False     NaN  restart
#
#        shortest_distance
# 0                    3.0
# 1                    3.0
# 2                    3.0
# 3                    2.0
# 4                    3.0
# ...                  ...
# 76188                3.0
# 76189                3.0
# 76190                3.0
# 76191                3.0
# 76192                3.0
#
# [76193 rows x 10 columns]

# %%
#remove all rows where the source or target article is not among the available articles in the dataset
path_overview = path_overview.drop(path_overview[~(path_overview['source'].isin(articles['article'].array))].index)
path_overview = path_overview.drop(path_overview[~(path_overview['target'].isin(articles['article'].array))].index)

# remove all rows where there is no path between the source article and target article
path_overview = path_overview.drop(path_overview[path_overview['shortest_distance'] == -1].index) 
path_overview.insert(4, 'shortest_distance', path_overview.pop('shortest_distance'))

# Translating article names from URL to latin characters
path_overview['source'].apply(unquote)
path_overview['target'].apply(unquote)

display(path_overview)
# Out:
#                      source               target   hashedIpAddress  \
# 0              14th_century  African_slave_trade  6a3701d319fc3754
# 1              14th_century  African_slave_trade  3824310e536af032
# 2              14th_century  African_slave_trade  415612e93584d30e
# 3              14th_century               Greece  64dd5cd342e3780c
# 4              14th_century      John_F._Kennedy  015245d773376aab
# ...                     ...                  ...               ...
# 76188           Franz_Kafka              Cholera  109ed71f571d86e9
# 76189        Modern_history            Hollandic  232f992e57d43e8d
# 76190  Computer_programming          The_Beatles  2e09a7224600a7cd
# 76191               Jamaica          Alan_Turing  60af9e2138051b96
# 76192           Mark_Antony              Feather  1cf0cbb3281049ab
#
#         timestamp  shortest_distance  durationInSec  game_path  completed  \
# 0      1297740409                3.0            166          8       True
# 1      1344753412                3.0             88          4       True
# 2      1349298640                3.0            138          7       True
# 3      1265613925                2.0             37          3       True
# 4      1366730828                3.0            175          6       True
# ...           ...                ...            ...        ...        ...
# 76188  1389787605                3.0            180          7      False
# 76189  1389787697                3.0              6          0      False
# 76190  1389798400                3.0           1900          4      False
# 76191  1389799481                3.0           1903          3      False
# 76192  1389822841                3.0            352          4      False
#
#        rating     type
# 0         NaN      NaN
# 1         3.0      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         3.0      NaN
# ...       ...      ...
# 76188     NaN  restart
# 76189     NaN  restart
# 76190     NaN  timeout
# 76191     NaN  timeout
# 76192     NaN  restart
#
# [76156 rows x 10 columns]

# %% [markdown]
# Another data wrangling step is to build a dataframe that contains the main categories of the articles.

# %%
# Apply the custom function extract_subject_category() to create a new 'subject_category' column
categories['subject_category'] = categories['category'].apply(extract_subject_category)

# Create a dataFrame with only the relevant columns
main_categories = categories[['article', 'subject_category']]

# Display the new DataFrame
main_categories.head()
# Out:
#              article subject_category
# 0  Áedán_mac_Gabráin          History
# 1  Áedán_mac_Gabráin           People
# 2              Åland        Countries
# 3              Åland        Geography
# 4      Édouard_Manet           People

# %% [markdown]
# Finally, we build a dictionary that maps articles country names to country names of the UN dataset and one that maps countries to their continent (world region).

# %%
# Below we find the articles which have different names to those outlined in the UN dataset. We then manually found the corresponding name in the UN
# dataset and created a dictionary to map article names -> UN dataset name

countries = main_categories[main_categories['subject_category'] == 'Countries']['article'].values
countries = [cntry.replace('_',' ') for cntry in countries]

# United Arab Emirates Problem -> Abu Dhabi / Dubai are not countries etc. If confusion, the country with biggest population is kept
countries_to_remove = ['Abu Dhabi', 'Dubai', 'Easter Island', 'Galápagos Islands', 'Korea', 'Abkhazia', 'Republic of China']
countries = [cntry for cntry in countries if cntry not in countries_to_remove]

countries_missing = []

for country in countries:
    country = country.replace('_',' ')
    if country not in UN_countries['Country or Area'].values:
        countries_missing.append(country)

# "China Problem" we keep Taiwan  -> Taiwan, Republic of China -> deleted (same as Taiwan),
# Tibet -> Tibet, People's Republic of China -> China

replacement_country_names = [
    'Åland Islands', 'Ireland', 'Bolivia (Plurinational State of)',
    'Brunei Darussalam', 'Côte d’Ivoire', 'Cabo Verde', 'Czechia',
    'Timor-Leste', 'Falkland Islands (Malvinas)', 'Micronesia (Federated States of)',
    'State of Palestine', 'Georgia', 'China, Hong Kong Special Administrative Region',
    'Iran (Islamic Republic of)', '', 'Lao People\'s Democratic Republic', 
    'Republic of Moldova', 'Netherlands (Kingdom of the)', 'Sint Maarten (Dutch part)', 
    'Democratic People\'s Republic of Korea', 'State of Palestine', 'China', 'Ireland',
    'North Macedonia', 'Russian Federation', 'Sao Tome and Principe', 'Serbia', 'Republic of Korea',
    "", 'Eswatini', 'Syrian Arab Republic', 'United Republic of Tanzania', 'Bahamas',
    'Gambia', 'Tibet', 'Türkiye', 'Turkish Republic of Northern Cyprus', 'United Kingdom of Great Britain and Northern Ireland',
    'United States of America', 'Holy See', 'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'State of Palestine'
]

replacement_countries = dict(zip(countries_missing, replacement_country_names))

# %%
UN_countries.head(30)
# Out:
#     Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0             1       World          2.0      Africa             15.0
# 1             1       World          2.0      Africa             15.0
# 2             1       World          2.0      Africa             15.0
# 3             1       World          2.0      Africa             15.0
# 4             1       World          2.0      Africa             15.0
# 5             1       World          2.0      Africa             15.0
# 6             1       World          2.0      Africa             15.0
# 7             1       World          2.0      Africa            202.0
# 8             1       World          2.0      Africa            202.0
# 9             1       World          2.0      Africa            202.0
# 10            1       World          2.0      Africa            202.0
# 11            1       World          2.0      Africa            202.0
# 12            1       World          2.0      Africa            202.0
# 13            1       World          2.0      Africa            202.0
# 14            1       World          2.0      Africa            202.0
# 15            1       World          2.0      Africa            202.0
# 16            1       World          2.0      Africa            202.0
# 17            1       World          2.0      Africa            202.0
# 18            1       World          2.0      Africa            202.0
# 19            1       World          2.0      Africa            202.0
# 20            1       World          2.0      Africa            202.0
# 21            1       World          2.0      Africa            202.0
# 22            1       World          2.0      Africa            202.0
# 23            1       World          2.0      Africa            202.0
# 24            1       World          2.0      Africa            202.0
# 25            1       World          2.0      Africa            202.0
# 26            1       World          2.0      Africa            202.0
# 27            1       World          2.0      Africa            202.0
# 28            1       World          2.0      Africa            202.0
# 29            1       World          2.0      Africa            202.0
#
#        Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0      Northern Africa                       NaN                      NaN
# 1      Northern Africa                       NaN                      NaN
# 2      Northern Africa                       NaN                      NaN
# 3      Northern Africa                       NaN                      NaN
# 4      Northern Africa                       NaN                      NaN
# 5      Northern Africa                       NaN                      NaN
# 6      Northern Africa                       NaN                      NaN
# 7   Sub-Saharan Africa                      14.0           Eastern Africa
# 8   Sub-Saharan Africa                      14.0           Eastern Africa
# 9   Sub-Saharan Africa                      14.0           Eastern Africa
# 10  Sub-Saharan Africa                      14.0           Eastern Africa
# 11  Sub-Saharan Africa                      14.0           Eastern Africa
# 12  Sub-Saharan Africa                      14.0           Eastern Africa
# 13  Sub-Saharan Africa                      14.0           Eastern Africa
# 14  Sub-Saharan Africa                      14.0           Eastern Africa
# 15  Sub-Saharan Africa                      14.0           Eastern Africa
# 16  Sub-Saharan Africa                      14.0           Eastern Africa
# 17  Sub-Saharan Africa                      14.0           Eastern Africa
# 18  Sub-Saharan Africa                      14.0           Eastern Africa
# 19  Sub-Saharan Africa                      14.0           Eastern Africa
# 20  Sub-Saharan Africa                      14.0           Eastern Africa
# 21  Sub-Saharan Africa                      14.0           Eastern Africa
# 22  Sub-Saharan Africa                      14.0           Eastern Africa
# 23  Sub-Saharan Africa                      14.0           Eastern Africa
# 24  Sub-Saharan Africa                      14.0           Eastern Africa
# 25  Sub-Saharan Africa                      14.0           Eastern Africa
# 26  Sub-Saharan Africa                      14.0           Eastern Africa
# 27  Sub-Saharan Africa                      14.0           Eastern Africa
# 28  Sub-Saharan Africa                      14.0           Eastern Africa
# 29  Sub-Saharan Africa                      17.0            Middle Africa
#
#                    Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0                          Algeria        12              DZ             DZA
# 1                            Egypt       818              EG             EGY
# 2                            Libya       434              LY             LBY
# 3                          Morocco       504              MA             MAR
# 4                            Sudan       729              SD             SDN
# 5                          Tunisia       788              TN             TUN
# 6                   Western Sahara       732              EH             ESH
# 7   British Indian Ocean Territory        86              IO             IOT
# 8                          Burundi       108              BI             BDI
# 9                          Comoros       174              KM             COM
# 10                        Djibouti       262              DJ             DJI
# 11                         Eritrea       232              ER             ERI
# 12                        Ethiopia       231              ET             ETH
# 13     French Southern Territories       260              TF             ATF
# 14                           Kenya       404              KE             KEN
# 15                      Madagascar       450              MG             MDG
# 16                          Malawi       454              MW             MWI
# 17                       Mauritius       480              MU             MUS
# 18                         Mayotte       175              YT             MYT
# 19                      Mozambique       508              MZ             MOZ
# 20                         Réunion       638              RE             REU
# 21                          Rwanda       646              RW             RWA
# 22                      Seychelles       690              SC             SYC
# 23                         Somalia       706              SO             SOM
# 24                     South Sudan       728              SS             SSD
# 25                          Uganda       800              UG             UGA
# 26     United Republic of Tanzania       834              TZ             TZA
# 27                          Zambia       894              ZM             ZMB
# 28                        Zimbabwe       716              ZW             ZWE
# 29                          Angola        24              AO             AGO
#
#    Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                                x                                     NaN
# 5                              NaN                                     NaN
# 6                              NaN                                     NaN
# 7                              NaN                                     NaN
# 8                                x                                       x
# 9                                x                                     NaN
# 10                               x                                     NaN
# 11                               x                                     NaN
# 12                               x                                       x
# 13                             NaN                                     NaN
# 14                             NaN                                     NaN
# 15                               x                                     NaN
# 16                               x                                       x
# 17                             NaN                                     NaN
# 18                             NaN                                     NaN
# 19                               x                                     NaN
# 20                             NaN                                     NaN
# 21                               x                                       x
# 22                             NaN                                     NaN
# 23                               x                                     NaN
# 24                               x                                       x
# 25                               x                                       x
# 26                               x                                     NaN
# 27                               x                                       x
# 28                             NaN                                       x
# 29                               x                                     NaN
#
#    Small Island Developing States (SIDS)
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                      x
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                     x
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                     x
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN

# %%
def get_region(country, DataFrame_with_regions, names_to_replace):
    """
    Returns the region for country, using names_to_replace for those with different names in DataFram_with_region than in the Wikispeedia Dataset
    """
    country = country.replace('_',' ')
    if country in DataFrame_with_regions['Country or Area'].values:
        region = DataFrame_with_regions[DataFrame_with_regions['Country or Area'] == country]['Sub-region Name'].values
        # print(type(region))
        return region[0]
    elif names_to_replace.get(country) != None:
        new_country = names_to_replace[country]
        region = DataFrame_with_regions[DataFrame_with_regions['Country or Area'] == new_country]['Sub-region Name'].values
        if len(region) > 0:
            return region[0]
        else:
            return ""
    else:
        return np.nan

# Creating a dictionary to map each country to its continent (region).
country_to_region = {}

for country in countries:
    country_to_region[country] = get_region(country, UN_countries, replacement_countries)

# 'Kosovo' and 'South_Ossetia' are added manually as they are not present in the UN dataframe.
country_to_region['Kosovo'] = 'Europe'
country_to_region['South_Ossetia'] = 'Asia'

df_country_region = pd.DataFrame.from_dict(country_to_region, 
                                           orient='index',
                                           dtype=None,
                                           columns=['region'])

df_country_region.reset_index(inplace=True)
df_country_region.rename(columns={"index": "article"}, inplace=True)

# %%
# Create UN_countries_by_economies DataFrame

# hard coded changes in country names that can't be read properly from the .csv file
read_csv_names = ['Turkiye', 'China Hong Kong Special Administrative Region', 'Cote d Ivoire']
new_names = ["Türkiye", "China, Hong Kong Special Administrative Region", "Côte d’Ivoire"]
UN_to_modify = UN_countries_by_economies_load.copy()
for i in range(len(read_csv_names)-1):
    country_index = np.where(UN_countries_by_economies_load['Country or Area']==read_csv_names[i])[0][0]
    UN_to_modify.at[country_index, 'Country or Area'] = new_names[i]

UN_countries_by_economies = pd.merge(UN_countries, UN_to_modify, how='left', on='Country or Area')[['Country or Area', 'Least Developed Countries (LDC)', 'Land Locked Developing Countries (LLDC)', 'Small Island Developing States (SIDS)', 'Economic classification']]
# Show countries that are missing an economic classification (should be 248-163=85)
# missing_countries = UN_countries_by_economies[UN_countries_by_economies['Economic classification'].isna()]['Country or Area'].values

# Rename Countries to match the names of English Wikipedia
replacement_countries_OLD_NEW = dict([(value, key) for key, value in replacement_countries.items()])
UN_countries_by_economies['Country or Area'] = UN_countries_by_economies['Country or Area'].map(replacement_countries_OLD_NEW).fillna(UN_countries_by_economies['Country or Area'])
UN_countries_by_economies = UN_countries_by_economies.sort_values('Country or Area').reset_index(drop=True)

# Check if everything went fine
display(UN_countries_by_economies[UN_countries_by_economies['Country or Area'] == "Taiwan"])
display(UN_countries_by_economies)
# Out:
#     Country or Area Least Developed Countries (LDC)  \
# 214          Taiwan                               x
#
#     Land Locked Developing Countries (LLDC)  \
# 214                                     NaN
#
#     Small Island Developing States (SIDS) Economic classification
# 214                                   NaN              Low-income
#     Country or Area Least Developed Countries (LDC)  \
# 0       Afghanistan                               x
# 1           Albania                             NaN
# 2           Algeria                             NaN
# 3    American Samoa                             NaN
# 4           Andorra                             NaN
# ..              ...                             ...
# 243  Western Sahara                             NaN
# 244           Yemen                               x
# 245          Zambia                               x
# 246        Zimbabwe                             NaN
# 247           Åland                             NaN
#
#     Land Locked Developing Countries (LLDC)  \
# 0                                         x
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 243                                     NaN
# 244                                     NaN
# 245                                       x
# 246                                       x
# 247                                     NaN
#
#     Small Island Developing States (SIDS) Economic classification
# 0                                     NaN                     NaN
# 1                                     NaN     Upper middle income
# 2                                     NaN     Upper middle income
# 3                                       x                     NaN
# 4                                     NaN                     NaN
# ..                                    ...                     ...
# 243                                   NaN                     NaN
# 244                                   NaN     Lower middle income
# 245                                   NaN     Lower middle income
# 246                                   NaN              Low-income
# 247                                   NaN                     NaN
#
# [248 rows x 5 columns]

# %%
# Create np.array with name of all articles that are about a country
countries = main_categories[main_categories['subject_category'] == 'Countries']['article'].values

# Directory where the .txt files are stored
directory = "data/plaintext_articles/" 

# Initialize an empty list to store the data
data = []

# Iterate over all countries
for country in countries:
    file_path = directory + country + '.txt'

# Open the file and read its content into a string
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            load_file_content = file.read()
            file_content = load_file_content[15:].replace("\n\n2007 Schools Wikipedia Selection", "")

    # Add filname, content and article length to the data list
        data.append((country, file_content, len(file_content)))

# Create a DataFrame from the data list
plaintext_articles = pd.DataFrame(data, columns=['Country', 'Article content', 'Article length'])
# Display the DataFrame
display(plaintext_articles)
# Out:
#             Country                                    Article content  \
# 0          Abkhazia  Abkhazia. Related subjects: Asian Countries;\n...
# 1         Abu_Dhabi  Abu Dhabi. Related subjects: Countries; Middle...
# 2       Afghanistan  Afghanistan. Related subjects: Asian Countries...
# 3           Albania  Albania. Related subjects: Countries; European...
# 4           Algeria  Algeria. Related subjects: African Countries;\...
# ..              ...                                                ...
# 215       West_Bank  West Bank. Related subjects: Countries; Middle...
# 216  Western_Sahara  Western Sahara. Related subjects: African Coun...
# 217           Yemen  Yemen. Related subjects: Countries; Middle Eas...
# 218          Zambia  Zambia. Related subjects: African Countries;\n...
# 219        Zimbabwe  Zimbabwe. Related subjects: African Countries;...
#
#      Article length
# 0             33592
# 1             12072
# 2             40240
# 3             24203
# 4             34081
# ..              ...
# 215           38456
# 216           25959
# 217           28075
# 218           31103
# 219           25206
#
# [220 rows x 3 columns]

# %%
# plot article lenght for each country

# first sort articles according the their length -> bars
sorted_articles = plaintext_articles.sort_values(by='Article length', ascending=False)

plt.figure(figsize=(20, 40))
plt.barh(sorted_articles['Country'], sorted_articles['Article length'], color='skyblue')
plt.xlabel('Article length')
plt.ylabel('Country')
plt.title('Article length for each country')

plt.show()

# %%
sorted_articles = plaintext_articles.sort_values(by='Article length', ascending=False)
plt.figure(figsize=(40, 20))
plt.bar(sorted_articles['Country'], sorted_articles['Article length'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Article length')
plt.title('Article length for each country')
# rotate x -> to be able to read
plt.xticks(rotation=90) 
plt.show()

# %%
# merge both dataframes
#total article lenght based on economic classification
merged_df = pd.merge(plaintext_articles, UN_countries_by_economies, left_on='Country', right_on='Country or Area')

#handle nan values? 
merged_df['Economic classification'].fillna('NAN values', inplace=True)

grouped_df = merged_df.groupby('Economic classification')['Article length'].sum().reset_index()

sorted_articles_by_economic_class = grouped_df.sort_values(by='Article length', ascending=False)

plt.figure(figsize=(20, 10))
plt.bar(sorted_articles_by_economic_class['Economic classification'], sorted_articles_by_economic_class['Article length'], color='skyblue')
plt.xlabel('Economic classification')
plt.ylabel('Total article length')
plt.title('Total article length based on economic classification')
plt.xticks(rotation=45) 


plt.show()

# %%
# take the mean instead of summing everything
# nan values

# %%
merged_df = pd.merge(plaintext_articles, UN_countries_by_economies, left_on='Country', right_on='Country or Area')
merged_df['Economic classification'].fillna('NAN values', inplace=True)
# Group by economic classification and calculate the mean of article length instead of sum
grouped_df = merged_df.groupby('Economic classification')['Article length'].mean().reset_index()
sorted_articles_by_economic_class = grouped_df.sort_values(by='Article length', ascending=False)
plt.figure(figsize=(20, 10))
plt.bar(sorted_articles_by_economic_class['Economic classification'], sorted_articles_by_economic_class['Article length'], color='skyblue')
plt.xlabel('Economic classification')
plt.ylabel('Average article length')
plt.title('Average article length based on economic classification')
plt.xticks(rotation=45)

plt.show()

# %%
merged_df = pd.merge(plaintext_articles, UN_countries, left_on='Country', right_on='Country or Area')
merged_df['Sub-region Name'].fillna('NAN values', inplace=True)
# Group by economic classification and calculate the mean of article length instead of sum
grouped_df = merged_df.groupby('Sub-region Name')['Article length'].mean().reset_index()
sorted_articles_by_economic_class = grouped_df.sort_values(by='Article length', ascending=False)
plt.figure(figsize=(20, 10))
plt.bar(sorted_articles_by_economic_class['Sub-region Name'], sorted_articles_by_economic_class['Article length'], color='skyblue')
plt.xlabel('Sub-region')
plt.ylabel('Average article length')
plt.title('Average article length based on sub-region')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Data analysis
# We now focus on perfoming descriptive statistics and initial analysis that supports our research questions.

# %%
# Plotting the distribution of countries in the dataset based on their continent, which we will consider their region.
continents_count = pd.DataFrame(country_to_region.values()).value_counts()


continents_count.plot(kind='bar')
#xticks = ["Asia", "Africa", "Americas", "Europe", "Oceania"]
xticks = ["Sub-Saharan Africa", "Latin America and the Caribbean", "Western Asia", "Southern Europe",
          "Northern Europe", "South-eastern Asia", "Eastern Europe", "Western Europe", "Southern Asia",
          "Northern Africa", "Eastern Asia", "Polynesia", "Central Asia", "Northern America",
          "Melanesia", "Australia and New Zealand", "Micronesia"]

l = np.arange(len(xticks))


plt.xticks(l, xticks)
plt.title("Counts of articles grouped by continents")
plt.xlabel("Continent")
plt.ylabel("Count")
plt.show()
continents_count
# Out:
# Sub-Saharan Africa                 46
# Latin America and the Caribbean    46
# Western Asia                       20
# Southern Europe                    16
# Northern Europe                    13
# South-eastern Asia                 11
# Eastern Europe                     10
# Western Europe                      9
# Southern Asia                       9
# Northern Africa                     7
# Eastern Asia                        6
# Polynesia                           5
# Central Asia                        5
# Northern America                    4
# Melanesia                           4
# Australia and New Zealand           4
#                                     3
# Micronesia                          2
# Asia                                1
# Europe                              1
# dtype: int64

# %% [markdown]
# This view of the number of country related articles by continent reflects that there is a reasonble number of articles present in the data set to perform our research.

# %% [markdown]
# ## First research questions
# We focus on the Wikipedia articles about countries and their hyperlink structure in the Wikispeedia dataset.
# ### Summary statistics for the number of in- and out- degrees of each region

# %%
links_outdegree = links.copy()
links_outdegree.columns = ['article','link_out']
out_degrees = links_outdegree.groupby('article').count()
out_degrees.sort_values(by='link_out', ascending=False, inplace=True)

links_indegree = links.copy()
links_indegree.columns = ['link_in','article']
in_degrees = links_indegree.groupby('article').count()
in_degrees.sort_values(by='link_in', ascending=False, inplace=True)

link_counts = out_degrees.merge(in_degrees, how='outer', on='article')

# %%
country_links = link_counts[link_counts.index.isin(countries)]
country_links.reset_index(inplace=True)
country_links = country_links.merge(df_country_region, on='article', how='left')
country_links.head()
# Out:
#              article  link_out  link_in        region
# 0      United_States     294.0   1551.0           NaN
# 1            Lebanon     192.0    114.0  Western Asia
# 2            Armenia     186.0     99.0  Western Asia
# 3  Georgia_(country)     180.0     84.0           NaN
# 4             Turkey     172.0    249.0

# %%
# Initialising empty dataframes
link_out_summary = pd.DataFrame()
link_in_summary = pd.DataFrame()

# Getting summary statistics for each region for in- and out- degrees
links_means = country_links[['link_out','link_in','region']].groupby(['region']).mean()
links_std = country_links[['link_out','link_in','region']].groupby(['region']).std()
links_max = country_links[['link_out','link_in','region']].groupby(['region']).max()
links_median = country_links[['link_out','link_in','region']].groupby(['region']).median()

for df, kind in [(links_means, 'mean'), (links_median, 'median'), (links_std, "std"), (links_max, 'max')]:
    link_out_summary[kind] = df['link_out']
    link_in_summary[kind] = df['link_in']

# %%
print("Link in descriptive statistics")
display(link_in_summary)
# Out:
# Link in descriptive statistics
#                                        mean  median         std    max
# region
#                                  249.000000   249.0         NaN  249.0
# Asia                               8.000000     8.0         NaN    8.0
# Australia and New Zealand        563.000000   563.0         NaN  563.0
# Central Asia                      63.400000    54.0   17.952716   94.0
# Eastern Asia                     534.500000   534.5   54.447222  573.0
# Eastern Europe                   179.888889   151.0  146.163816  520.0
# Europe                            37.000000    37.0         NaN   37.0
# Latin America and the Caribbean   82.931034    63.0   65.032372  274.0
# Melanesia                         42.000000    42.0    7.071068   47.0
# Micronesia                        43.000000    43.0         NaN   43.0
# Northern Africa                  154.000000   113.0  103.440804  362.0
# Northern America                 228.333333    69.0  297.000561  571.0
# Northern Europe                  176.444444   155.0   92.869682  319.0
# Polynesia                         28.666667    29.0    2.516611   31.0
# South-eastern Asia               118.200000   110.0   48.868986  202.0
# Southern Asia                    178.250000   121.0  186.715789  611.0
# Southern Europe                  198.090909    93.0  191.923659  550.0
# Sub-Saharan Africa                72.514286    68.0   20.779474  134.0
# Western Asia                     101.866667    82.0   52.276554  236.0
# Western Europe                   326.333333   232.0  318.397158  959.0

# %%
print("Link out descriptive statistics")
display(link_out_summary)
# Out:
# Link out descriptive statistics
#                                        mean  median        std    max
# region
#                                  172.000000   172.0        NaN  172.0
# Asia                              17.000000    17.0        NaN   17.0
# Australia and New Zealand         86.000000    86.0        NaN   86.0
# Central Asia                      36.000000    37.0   5.431390   42.0
# Eastern Asia                      94.000000    94.0   5.656854   98.0
# Eastern Europe                    66.777778    58.0  35.720365  145.0
# Europe                            46.000000    46.0        NaN   46.0
# Latin America and the Caribbean   49.200000    41.0  32.286861  163.0
# Melanesia                         28.000000    28.0   0.000000   28.0
# Micronesia                        26.000000    26.0        NaN   26.0
# Northern Africa                   69.166667    64.0  33.825533  132.0
# Northern America                  46.000000    40.0  14.933185   63.0
# Northern Europe                   52.727273    51.0  26.344225   96.0
# Polynesia                         29.333333    29.0   4.509250   34.0
# South-eastern Asia                44.600000    47.0  12.482877   62.0
# Southern Asia                     59.000000    49.5  24.979992  108.0
# Southern Europe                   95.818182    89.0  36.323046  139.0
# Sub-Saharan Africa                66.685714    34.0  51.935351  162.0
# Western Asia                      84.533333    54.0  62.201133  192.0
# Western Europe                    77.888889    61.0  46.878685  169.0

# %% [markdown]
# Here the number of links in and out appears to vary significantly within countries and continent, this variation could be correlated to the article length or else, which supports our first research question.

# %% [markdown]
# Is it really necessary to have a plot for link_in and link_out for each country?

# %%
# to sort and group --> group by article and sum the link_in and link_out counts
grouped_data = country_links.groupby('article')[['link_in', 'link_out']].sum()
grouped_data['total_links'] = grouped_data['link_in'] + grouped_data['link_out']
# sort data in descending order based on total_links
grouped_data = grouped_data.sort_values(by='total_links', ascending=False)
fig, ax = plt.subplots(figsize=(40, 20))
grouped_data[['link_in', 'link_out']].plot(kind='bar', ax=ax, width=0.8)
plt.xlabel('Country')
plt.ylabel('Number of links')
plt.title('Number of link_in and link_out for each country')

plt.show()

# %% [markdown]
# we notice that for the 20 top countries approximately, we get way more link_in then link_out
# this clearly suggets imbalance in the linking structure of wikispeedia
# articles with more links in "attracts" more references from other articles
# hence in navigation paths --> Users may navigate through the encyclopedia in a way that results in certain articles
# being linked to more frequently than others

# %%
grouped_data = country_links.groupby('article')[['link_in', 'link_out']].sum()

grouped_data['total_links'] = grouped_data['link_in'] + grouped_data['link_out']

grouped_data = grouped_data.sort_values(by='total_links', ascending=False)

top_10_countries = grouped_data.head(10)

fig, ax = plt.subplots(figsize=(12, 6))
top_10_countries[['link_in', 'link_out']].plot(kind='bar', ax=ax, width=0.8)

plt.xlabel('Country')
plt.ylabel('Number of links')
plt.title('Top 10 Countries: Number of link_in and link_out')

# Display the plot
plt.show()

# %% [markdown]
# ## Second section of research questions
# The focus is on the pathways that were taken by the players, where the target or goal article of the game is a country.
# ### Finished paths and target countries

# %%
country_path_overview = path_overview[path_overview['target'].isin(countries)]

country_path_overview = country_path_overview.merge(df_country_region, 
                                                    left_on='target', 
                                                    right_on='article', 
                                                    how='left').drop(['article'], axis=1)

# %%
region_completed_count = country_path_overview[['region','completed','target']].groupby(['region','completed']).count()
region_count = country_path_overview[['region','target']].groupby(['region']).count()
# region_completed_count.set_index(['region'], inplace=True)
region_count
# Out:
#                                  target
# region
#                                      23
# Asia                                  5
# Australia and New Zealand            40
# Central Asia                         96
# Eastern Asia                        214
# Eastern Europe                      274
# Europe                               15
# Latin America and the Caribbean     608
# Melanesia                            27
# Micronesia                            6
# Northern Africa                     123
# Northern America                    122
# Northern Europe                     227
# Polynesia                            34
# South-eastern Asia                  205
# Southern Asia                       219
# Southern Europe                     251
# Sub-Saharan Africa                  568
# Western Asia                        389
# Western Europe                      210

# %% [markdown]
# Each continent is reasonably represented in terms of number of times it was a target of the game, this supports the fact that should be enough data for us to analysis the ratio of finished/unfinished pathways.

# %%
proportions = pd.DataFrame()

for region, completion in region_completed_count.index:
    proportion = region_completed_count.loc[(region, completion)] / region_count.loc[region]
    if completion:
        status = 'finished'
    else:
         status = 'unfinished'
    print(f"Proportion of {status} paths with {region} as target: {round(proportion.values[0]*100,4)}%")
# Out:
# Proportion of unfinished paths with  as target: 8.6957%
# Proportion of finished paths with  as target: 91.3043%
# Proportion of finished paths with Asia as target: 100.0%
# Proportion of unfinished paths with Australia and New Zealand as target: 2.5%
# Proportion of finished paths with Australia and New Zealand as target: 97.5%
# Proportion of unfinished paths with Central Asia as target: 18.75%
# Proportion of finished paths with Central Asia as target: 81.25%
# Proportion of unfinished paths with Eastern Asia as target: 7.9439%
# Proportion of finished paths with Eastern Asia as target: 92.0561%
# Proportion of unfinished paths with Eastern Europe as target: 9.854%
# Proportion of finished paths with Eastern Europe as target: 90.146%
# Proportion of unfinished paths with Europe as target: 33.3333%
# Proportion of finished paths with Europe as target: 66.6667%
# Proportion of unfinished paths with Latin America and the Caribbean as target: 13.9803%
# Proportion of finished paths with Latin America and the Caribbean as target: 86.0197%
# Proportion of unfinished paths with Melanesia as target: 25.9259%
# Proportion of finished paths with Melanesia as target: 74.0741%
# Proportion of unfinished paths with Micronesia as target: 16.6667%
# Proportion of finished paths with Micronesia as target: 83.3333%
# Proportion of unfinished paths with Northern Africa as target: 12.1951%
# Proportion of finished paths with Northern Africa as target: 87.8049%
# Proportion of unfinished paths with Northern America as target: 4.0984%
# Proportion of finished paths with Northern America as target: 95.9016%
# Proportion of unfinished paths with Northern Europe as target: 5.7269%
# Proportion of finished paths with Northern Europe as target: 94.2731%
# Proportion of unfinished paths with Polynesia as target: 38.2353%
# Proportion of finished paths with Polynesia as target: 61.7647%
# Proportion of unfinished paths with South-eastern Asia as target: 15.122%
# Proportion of finished paths with South-eastern Asia as target: 84.878%
# Proportion of unfinished paths with Southern Asia as target: 8.6758%
# Proportion of finished paths with Southern Asia as target: 91.3242%
# Proportion of unfinished paths with Southern Europe as target: 10.757%
# Proportion of finished paths with Southern Europe as target: 89.243%
# Proportion of unfinished paths with Sub-Saharan Africa as target: 11.4437%
# Proportion of finished paths with Sub-Saharan Africa as target: 88.5563%
# Proportion of unfinished paths with Western Asia as target: 13.6247%
# Proportion of finished paths with Western Asia as target: 86.3753%
# Proportion of unfinished paths with Western Europe as target: 8.5714%
# Proportion of finished paths with Western Europe as target: 91.4286%

# %% [markdown]
# Basic statistics representing the ratio of finished vs unfinished paths towards a country of a specific continent already reflects some difference between the continents. Europe and Africa have the highest finish rate in front of Asia, Oceania and Americas, interestingly Africa was almost two times less a target as Asia. Further correlation test such as the Pearson correlation test could be applied to answer the 3rd research question.

# %% [markdown]
# ### Length of pathway analysis

# %%
country_path_overview.head(30)
# Out:
#                             source                   target   hashedIpAddress  \
# 0                     14th_century                   Greece  64dd5cd342e3780c
# 1   2005_Atlantic_hurricane_season                    Spain  0d57c8c57d75e2f5
# 2   2005_Atlantic_hurricane_season            Liechtenstein  0ec465e516314a56
# 3   2005_Atlantic_hurricane_season            Liechtenstein  1dbbba9e540a9b9b
# 4   2005_Atlantic_hurricane_season                   Sweden  2134400014dd016d
# 5   2005_Atlantic_hurricane_season                  Burundi  7299b9df41e65878
# 6                           Africa                   Mexico  2c5d0cf354f0177c
# 7                           Africa                  Vietnam  71868ac97147cf14
# 8                           Africa                Australia  0a80ead420fab166
# 9             Age_of_Enlightenment               Kazakhstan  3ed032c42eb483ec
# 10            Age_of_Enlightenment               Kazakhstan  4490509711b65e17
# 11            Age_of_Enlightenment               Kazakhstan  6e69387557f296c0
# 12            Age_of_Enlightenment               Kazakhstan  0d57c8c57d75e2f5
# 13            Age_of_Enlightenment               Kazakhstan  7f38002d7b41f381
# 14            Age_of_Enlightenment               Kazakhstan  5f22535607b1d77d
# 15            Age_of_Enlightenment               Kazakhstan  297eb11414b9c099
# 16            Age_of_Enlightenment               Kazakhstan  7b2e1e173472eff7
# 17            Age_of_Enlightenment               Kazakhstan  5f3d508c1360f76c
# 18            Age_of_Enlightenment               Kazakhstan  7627a4092dc66898
# 19                            AIDS                  Germany  6de209496bb66f66
# 20                            AIDS                 Maldives  1d6d23495d47977c
# 21                            AIDS  Palestinian_territories  0d57c8c57d75e2f5
# 22                        Aircraft               Bangladesh  0299542414c3f20a
# 23              American_Civil_War                   Poland  153c1af00eb0d932
# 24                        Anaconda                    Japan  0e430eab6ff4a1bc
# 25                        Anaconda                    Sudan  736950d865ef371b
# 26                       Animation                  Somalia  2e477f1847b506b5
# 27                      Anne_Frank                  Ireland  0d57c8c57d75e2f5
# 28                      Anne_Frank                  Ireland  28775cfc5dccd743
# 29                      Anne_Frank                  Ireland  25abf3566714fd52
#
#      timestamp  shortest_distance  durationInSec  game_path  completed  \
# 0   1265613925                2.0             37          3       True
# 1   1287268005                1.0             22          3       True
# 2   1249908585                2.0            391          5       True
# 3   1346912342                2.0            227          2       True
# 4   1366612470                2.0             53          4       True
# 5   1249103098                2.0            148          3       True
# 6   1251954210                2.0             36          3       True
# 7   1260294162                2.0             46          3       True
# 8   1344299147                2.0             20          2       True
# 9   1224072942                2.0            119          9       True
# 10  1226532587                2.0             45          4       True
# 11  1247947480                2.0            115          6       True
# 12  1294259934                2.0             75          4       True
# 13  1341538667                2.0            333          4       True
# 14  1348238896                2.0             45          6       True
# 15  1349458902                2.0             95          4       True
# 16  1349751572                2.0            194          6       True
# 17  1351113682                2.0            229          6       True
# 18  1354336008                2.0             23          3       True
# 19  1328937740                1.0             44          2       True
# 20  1223954843                2.0            144          5       True
# 21  1287452198                2.0             67          3       True
# 22  1258554860                2.0             65          2       True
# 23  1374904054                2.0             47          3       True
# 24  1220457648                2.0            958          3       True
# 25  1253487898                3.0             36          3       True
# 26  1250111414                3.0             40          3       True
# 27  1279902516                2.0             88          4       True
# 28  1304219108                2.0            101          4       True
# 29  1338076909                2.0             27          4       True
#
#     rating type                           region
# 0      NaN  NaN                  Southern Europe
# 1      1.0  NaN                  Southern Europe
# 2      2.0  NaN                   Western Europe
# 3      5.0  NaN                   Western Europe
# 4      NaN  NaN                  Northern Europe
# 5      2.0  NaN               Sub-Saharan Africa
# 6      1.0  NaN  Latin America and the Caribbean
# 7      NaN  NaN                     Western Asia
# 8      NaN  NaN        Australia and New Zealand
# 9      4.0  NaN                     Central Asia
# 10     NaN  NaN                     Central Asia
# 11     NaN  NaN                     Central Asia
# 12     1.0  NaN                     Central Asia
# 13     NaN  NaN                     Central Asia
# 14     NaN  NaN                     Central Asia
# 15     NaN  NaN                     Central Asia
# 16     5.0  NaN                     Central Asia
# 17     3.0  NaN                     Central Asia
# 18     2.0  NaN                     Central Asia
# 19     1.0  NaN                   Western Europe
# 20     3.0  NaN                    Southern Asia
# 21     1.0  NaN                              NaN
# 22     NaN  NaN                    Southern Asia
# 23     NaN  NaN                   Eastern Europe
# 24     1.0  NaN                     Eastern Asia
# 25     NaN  NaN                  Northern Africa
# 26     1.0  NaN               Sub-Saharan Africa
# 27     1.0  NaN                  Northern Europe
# 28     2.0  NaN                  Northern Europe
# 29     NaN  NaN                  Northern Europe

# %%
regions_paths = country_path_overview[['region','shortest_distance','game_path']][country_path_overview['completed']==True].groupby(by=['region','shortest_distance']).mean().reset_index()

# %%
regions_paths_1 = regions_paths[regions_paths['shortest_distance'] == 1]
regions_paths_2 = regions_paths[regions_paths['shortest_distance'] == 2]
regions_paths_3 = regions_paths[regions_paths['shortest_distance'] == 3]
regions_paths_4 = regions_paths[regions_paths['shortest_distance'] == 4]

# %%
figs, axs = plt.subplots(2,2, figsize=(10,8))

figs.suptitle("Median played path lengths for finished games, separated by shortest path length")

axs[0,0].bar(regions_paths_1['region'], regions_paths_1['game_path'])
axs[0,0].set_title("Shortest path = 1")
axs[0,0].set_xlabel("Region")
axs[0,0].set_ylabel("Median played path length")

axs[0,1].bar(regions_paths_2['region'], regions_paths_2['game_path'])
axs[0,1].set_title("Shortest path = 2")
axs[0,1].set_xlabel("Region")
axs[0,1].set_ylabel("Median played path length")

axs[1,0].bar(regions_paths_3['region'], regions_paths_3['game_path'])
axs[1,0].set_title("Shortest path = 3")
axs[1,0].set_xlabel("Region")
axs[1,0].set_ylabel("Median played path length")

axs[1,1].bar(regions_paths_4['region'], regions_paths_4['game_path'])
axs[1,1].set_title("Shortest path = 4")
axs[1,1].set_xlabel("Region")
axs[1,1].set_ylabel("Median played path length")

plt.tight_layout()
plt.show()

# %% [markdown]
#  keep only rows from country_overview where target is a country + display lenght and time needed and see difference between countries in a plot. See which countries have take less time and which are longer.

# %%
UN_countries_by_economies.head()
# Out:
#   Country or Area Least Developed Countries (LDC)  \
# 0     Afghanistan                               x
# 1         Albania                             NaN
# 2         Algeria                             NaN
# 3  American Samoa                             NaN
# 4         Andorra                             NaN
#
#   Land Locked Developing Countries (LLDC)  \
# 0                                       x
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Small Island Developing States (SIDS) Economic classification
# 0                                   NaN                     NaN
# 1                                   NaN     Upper middle income
# 2                                   NaN     Upper middle income
# 3                                     x                     NaN
# 4                                   NaN                     NaN

# %%
# first we merge both dataframe based on target
merged_data = pd.merge(country_path_overview, UN_countries_by_economies,
                       left_on='target', right_on='Country or Area', how='left')

completed_articles = merged_data[merged_data['completed'] == True]
economic_classification_counts = completed_articles.groupby('Economic classification').size()
fig, ax = plt.subplots(figsize=(5, 5))
economic_classification_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=ax, colors=['blue', 'green', 'coral', 'yellow'])
plt.axis('equal') 
plt.title('Percentage of completed games per economic classification')
plt.show()

# %%
# first we merge both dataframe based on target
merged_data = pd.merge(country_path_overview, UN_countries_by_economies,
                       left_on='target', right_on='Country or Area', how='left')

completed_articles = merged_data[merged_data['completed'] == False]
economic_classification_counts = completed_articles.groupby('Economic classification').size()
fig, ax = plt.subplots(figsize=(5, 5))
economic_classification_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=ax, colors=['blue', 'green', 'coral', 'yellow'])
plt.axis('equal') 
plt.title('Percentage of completed games per economic classification')
plt.show()

# %%
# first we merge both dataframe based on target
merged_data = pd.merge(country_path_overview, UN_countries,
                       left_on='target', right_on='Country or Area', how='left')

completed_articles = merged_data[merged_data['completed'] == True]
economic_classification_counts = completed_articles.groupby('Sub-region Name').size()
fig, ax = plt.subplots(figsize=(10, 10))
economic_classification_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, ax=ax, colors=['blue', 'green', 'coral', 'yellow'])
plt.axis('equal') 
plt.title('Percentage of completed games per economic classification')
plt.show()

# %%
merged_data = pd.merge(country_path_overview, UN_countries_by_economies,
                       left_on='target', right_on='Country or Area', how='left')
completed_articles = merged_data[merged_data['completed'] == True]
grouped_data = completed_articles.groupby(['Economic classification', 'game_path']).size().unstack(fill_value=0)
fig, ax = plt.subplots(figsize=(12, 8))
grouped_data.plot(kind='bar', ax=ax)
plt.xlabel('Economic classification')
plt.ylabel('Number of games')
plt.title('Number of games per economic classification and game path')
plt.show()

# %%
merged_data = pd.merge(country_path_overview, UN_countries_by_economies,
                       left_on='target', right_on='Country or Area', how='left')
completed_articles = merged_data[merged_data['completed'] == True]
average_game_path = completed_articles.groupby('Economic classification')['game_path'].mean()
fig, ax = plt.subplots(figsize=(12, 8))
average_game_path.plot(kind='bar', ax=ax, color='skyblue')
plt.xlabel('Economic classification')
plt.ylabel('Average game path')
plt.title('Average game path per economic classification')
plt.show()

# %%
merged_data = pd.merge(country_path_overview, UN_countries_by_economies,
                       left_on='target', right_on='Country or Area', how='left')

completed_articles = merged_data
article_counts = completed_articles['Economic classification'].value_counts()
fig, ax = plt.subplots(figsize=(12, 8))
article_counts.plot(kind='bar', ax=ax, color='skyblue')

plt.xlabel('Economic classification')
plt.ylabel('Number of articles')
plt.title('Number of articles per economic classification')
plt.show()

# %% [markdown]
#  # frequency of article C's involvement in pathways where it was neither the start nor the target

# %%
# expand the finished paths
path_fin2 = paths_finished.copy()
path_fin2 = path_fin2.assign(source=paths_finished['path'].apply(lambda x: seperate_path(x)[0]),
                           target=paths_finished['path'].apply(lambda x: seperate_path(x)[1]),
                           game_path=paths_finished['path'].apply(lambda x: seperate_path(x)[2]),
                           completed=True,
                           paths=paths_finished['path'])

# expand the unfinished paths
path_ufin2 = paths_unfinished.copy()
path_ufin2 = path_ufin2.assign(source=paths_unfinished['path'].apply(lambda x: seperate_path(x)[0]),
                             failure_article=paths_unfinished['path'].apply(lambda x: seperate_path(x)[1]),
                             game_path=paths_unfinished['path'].apply(lambda x: seperate_path(x)[2]),
                             completed=False,
                             target=paths_unfinished["target"],
                             paths=paths_unfinished['path'])

# construct a new dataframe: path_overview
path_overview2 = pd.concat([path_fin2, path_ufin2], ignore_index=True)[["source", "target",  "hashedIpAddress", "timestamp",
                                                                     "durationInSec", "game_path",
                                                                     "completed", "rating","type", "paths"]]
path_overview2.head()
# Out:
#          source               target   hashedIpAddress   timestamp  \
# 0  14th_century  African_slave_trade  6a3701d319fc3754  1297740409
# 1  14th_century  African_slave_trade  3824310e536af032  1344753412
# 2  14th_century  African_slave_trade  415612e93584d30e  1349298640
# 3  14th_century               Greece  64dd5cd342e3780c  1265613925
# 4  14th_century      John_F._Kennedy  015245d773376aab  1366730828
#
#    durationInSec  game_path  completed  rating type  \
# 0            166          8       True     NaN  NaN
# 1             88          4       True     3.0  NaN
# 2            138          7       True     NaN  NaN
# 3             37          3       True     NaN  NaN
# 4            175          6       True     3.0  NaN
#
#                                                paths
# 0  14th_century;15th_century;16th_century;Pacific...
# 1  14th_century;Europe;Africa;Atlantic_slave_trad...
# 2  14th_century;Niger;Nigeria;British_Empire;Slav...
# 3     14th_century;Renaissance;Ancient_Greece;Greece
# 4  14th_century;Italy;Roman_Catholic_Church;HIV;R...

# %%
UN_countries_by_economies_load
# Out:
#                            Country or Area Economic classification
# 0                                Australia             High-income
# 1                                  Austria             High-income
# 2                                  Bahrain             High-income
# 3                                 Barbados             High-income
# 4                                  Belgium             High-income
# ..                                     ...                     ...
# 158                               Zimbabwe              Low-income
# 159                  Sao Tome and Principe     Lower middle income
# 160  Democratic People's Republic of Korea              Low-income
# 161                               Cambodia     Lower middle income
# 162       Lao People's Democratic Republic     Lower middle income
#
# [163 rows x 2 columns]

# %%
plaintext_articles
# Out:
#             Country                                    Article content  \
# 0          Abkhazia  Abkhazia. Related subjects: Asian Countries;\n...
# 1         Abu_Dhabi  Abu Dhabi. Related subjects: Countries; Middle...
# 2       Afghanistan  Afghanistan. Related subjects: Asian Countries...
# 3           Albania  Albania. Related subjects: Countries; European...
# 4           Algeria  Algeria. Related subjects: African Countries;\...
# ..              ...                                                ...
# 215       West_Bank  West Bank. Related subjects: Countries; Middle...
# 216  Western_Sahara  Western Sahara. Related subjects: African Coun...
# 217           Yemen  Yemen. Related subjects: Countries; Middle Eas...
# 218          Zambia  Zambia. Related subjects: African Countries;\n...
# 219        Zimbabwe  Zimbabwe. Related subjects: African Countries;...
#
#      Article length
# 0             33592
# 1             12072
# 2             40240
# 3             24203
# 4             34081
# ..              ...
# 215           38456
# 216           25959
# 217           28075
# 218           31103
# 219           25206
#
# [220 rows x 3 columns]

# %%
print("hello")
# Out:
# hello

# %%
# Split "paths" in path_overview2
path_overview2['paths'] = path_overview2['paths'].str.replace(';',' ')
country_frequencies = {}  # dict to store frequencies
display(path_overview2)
# Out:
#                      source               target   hashedIpAddress  \
# 0              14th_century  African_slave_trade  6a3701d319fc3754
# 1              14th_century  African_slave_trade  3824310e536af032
# 2              14th_century  African_slave_trade  415612e93584d30e
# 3              14th_century               Greece  64dd5cd342e3780c
# 4              14th_century      John_F._Kennedy  015245d773376aab
# ...                     ...                  ...               ...
# 76188           Franz_Kafka              Cholera  109ed71f571d86e9
# 76189        Modern_history            Hollandic  232f992e57d43e8d
# 76190  Computer_programming          The_Beatles  2e09a7224600a7cd
# 76191               Jamaica          Alan_Turing  60af9e2138051b96
# 76192           Mark_Antony              Feather  1cf0cbb3281049ab
#
#         timestamp  durationInSec  game_path  completed  rating     type  \
# 0      1297740409            166          8       True     NaN      NaN
# 1      1344753412             88          4       True     3.0      NaN
# 2      1349298640            138          7       True     NaN      NaN
# 3      1265613925             37          3       True     NaN      NaN
# 4      1366730828            175          6       True     3.0      NaN
# ...           ...            ...        ...        ...     ...      ...
# 76188  1389787605            180          7      False     NaN  restart
# 76189  1389787697              6          0      False     NaN  restart
# 76190  1389798400           1900          4      False     NaN  timeout
# 76191  1389799481           1903          3      False     NaN  timeout
# 76192  1389822841            352          4      False     NaN  restart
#
#                                                    paths
# 0      14th_century 15th_century 16th_century Pacific...
# 1      14th_century Europe Africa Atlantic_slave_trad...
# 2      14th_century Niger Nigeria British_Empire Slav...
# 3         14th_century Renaissance Ancient_Greece Greece
# 4      14th_century Italy Roman_Catholic_Church HIV R...
# ...                                                  ...
# 76188  Franz_Kafka Tuberculosis World_Health_Organiza...
# 76189                                     Modern_history
# 76190  Computer_programming Linguistics Culture Popul...
# 76191  Jamaica United_Kingdom World_War_II Battle_of_...
# 76192          Mark_Antony Rome Tennis Hawk-Eye Computer
#
# [76193 rows x 10 columns]

# %%
# 218 rows -> 2 countries are not even in one path
country_counts = {}

for _, row in path_overview2.iterrows():
    articles = row['paths'].split()
    for country in plaintext_articles['Country']:
        # check it is not target
        if country in articles and country != row['source'] and country != row['target']:
            # Count occurrences of the country in the paths
            count = articles.count(country)

            # update dict
            country_counts.setdefault(country, 0)
            country_counts[country] += count

country_counts_df = pd.DataFrame(list(country_counts.items()), columns=['Country', 'Count'])

print(country_counts_df)
# Out:
#                                  Country  Count
# 0                                  Niger     21
# 1                                Nigeria     76
# 2                                  Italy   1143
# 3                          United_States  12366
# 4                                  China   1227
# ..                                   ...    ...
# 213                                Aruba      6
# 214                               Kosovo      2
# 215                        South_Ossetia      1
# 216  Turkish_Republic_of_Northern_Cyprus      1
# 217       British_Indian_Ocean_Territory      1
#
# [218 rows x 2 columns]

# %%
country_counts_df = country_counts_df.sort_values(by='Count', ascending=False)
print(country_counts_df)
# Out:
#                                  Country  Count
# 3                          United_States  12366
# 24                        United_Kingdom   5278
# 7                                 France   2201
# 21                               Germany   2121
# 6                                  India   1722
# ..                                   ...    ...
# 214                               Kosovo      2
# 207                Serbia_and_Montenegro      1
# 215                        South_Ossetia      1
# 216  Turkish_Republic_of_Northern_Cyprus      1
# 217       British_Indian_Ocean_Territory      1
#
# [218 rows x 2 columns]

# %%
country_counts = {}

for _, row in path_overview2.iterrows():
    # Split the paths into individual articles
    articles = row['paths'].split()

    # Iterate over countries in plaintext_articles
    for country in plaintext_articles['Country']:
        # Check if the country appears in the paths and is not a source or target
        if country in articles and country != row['source'] and country != row['target']:
            # Count occurrences of the country in the paths
            count = articles.count(country)

            country_counts.setdefault(country, 0)
            country_counts[country] += count

# Include countries not in any paths with a count of 0
for country in plaintext_articles['Country']:
    if country not in country_counts:
        country_counts[country] = 0
country_counts_df = pd.DataFrame(list(country_counts.items()), columns=['Country', 'Count'])
country_counts_df = country_counts_df.sort_values(by='Count', ascending=False)

print(country_counts_df)
# Out:
#                                  Country  Count
# 3                          United_States  12366
# 24                        United_Kingdom   5278
# 7                                 France   2201
# 21                               Germany   2121
# 6                                  India   1722
# ..                                   ...    ...
# 215                        South_Ossetia      1
# 216  Turkish_Republic_of_Northern_Cyprus      1
# 217       British_Indian_Ocean_Territory      1
# 218                             Abkhazia      0
# 219                              Bahamas      0
#
# [220 rows x 2 columns]

# %%
# plot of frequency of country's involvment in path where it was neither a source nor a target

fig, ax = plt.subplots(figsize=(30, 15))
country_counts_df.plot(kind='bar', x='Country', y='Count', ax=ax, color='skyblue', log= True)

plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Count of occurrences in paths for Each Country')

plt.show()

# %%
# same count but for sub-regions

# %%
UN_countries
# Out:
#      Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0              1       World          2.0      Africa             15.0
# 1              1       World          2.0      Africa             15.0
# 2              1       World          2.0      Africa             15.0
# 3              1       World          2.0      Africa             15.0
# 4              1       World          2.0      Africa             15.0
# ..           ...         ...          ...         ...              ...
# 243            1       World          9.0     Oceania             61.0
# 244            1       World          9.0     Oceania             61.0
# 245            1       World          9.0     Oceania             61.0
# 246            1       World          9.0     Oceania             61.0
# 247            1       World          9.0     Oceania             61.0
#
#      Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0    Northern Africa                       NaN                      NaN
# 1    Northern Africa                       NaN                      NaN
# 2    Northern Africa                       NaN                      NaN
# 3    Northern Africa                       NaN                      NaN
# 4    Northern Africa                       NaN                      NaN
# ..               ...                       ...                      ...
# 243        Polynesia                       NaN                      NaN
# 244        Polynesia                       NaN                      NaN
# 245        Polynesia                       NaN                      NaN
# 246        Polynesia                       NaN                      NaN
# 247        Polynesia                       NaN                      NaN
#
#                Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0                      Algeria        12              DZ             DZA
# 1                        Egypt       818              EG             EGY
# 2                        Libya       434              LY             LBY
# 3                      Morocco       504              MA             MAR
# 4                        Sudan       729              SD             SDN
# ..                         ...       ...             ...             ...
# 243                      Samoa       882              WS             WSM
# 244                    Tokelau       772              TK             TKL
# 245                      Tonga       776              TO             TON
# 246                     Tuvalu       798              TV             TUV
# 247  Wallis and Futuna Islands       876              WF             WLF
#
#     Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                                 x                                     NaN
# ..                              ...                                     ...
# 243                             NaN                                     NaN
# 244                             NaN                                     NaN
# 245                             NaN                                     NaN
# 246                               x                                     NaN
# 247                             NaN                                     NaN
#
#     Small Island Developing States (SIDS)
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 243                                     x
# 244                                   NaN
# 245                                     x
# 246                                     x
# 247                                   NaN
#
# [248 rows x 15 columns]

# %%
# create a new dataframe with mean of counts sub-region
# Merge dataframes on the 'Country' and 'Country or Area' columns
merged_data = pd.merge(country_counts_df, UN_countries,
                       left_on='Country', right_on='Country or Area', how='left')

# Group by 'Sub-region Name' and calculate the mean count
subregion_counts = merged_data.groupby('Sub-region Name')['Count'].mean().reset_index()
subregion_counts_sorted = subregion_counts.sort_values(by='Count', ascending=False)
# Display the resulting dataframe
print(subregion_counts_sorted)
# Out:
#                     Sub-region Name        Count
# 2                      Eastern Asia  1256.000000
# 0         Australia and New Zealand  1217.000000
# 16                   Western Europe   650.500000
# 8                  Northern America   429.333333
# 12                    Southern Asia   309.428571
# 9                   Northern Europe   276.888889
# 13                  Southern Europe   267.545455
# 7                   Northern Africa   223.000000
# 4   Latin America and the Caribbean   112.321429
# 11               South-eastern Asia   104.142857
# 3                    Eastern Europe    86.000000
# 15                     Western Asia    76.666667
# 14               Sub-Saharan Africa    50.031250
# 1                      Central Asia    24.600000
# 6                        Micronesia    24.000000
# 5                         Melanesia    12.500000
# 10                        Polynesia     7.666667

# %% [markdown]
# # draft

# %%
# Sample data
plaintext_articles_data = {'Country': ['CountryA', 'CountryB', 'CountryC']}
path_overview2_data = {'source': ['SourceA', 'SourceB', 'SourceC'],
                       'target': ['TargetA', 'TargetB', 'TargetC'],
                       'paths': ['14th_century 15th_century CountryA Pacific',
                                 '16th_century CountryB CountryB 17th_century',
                                 'CountryC 18th_century 19th_century']}

plaintext_articles = pd.DataFrame(plaintext_articles_data)
path_overview2 = pd.DataFrame(path_overview2_data)

country_counts = {}

for _, row in path_overview2.iterrows():

    articles = row['paths'].split()
    for country in plaintext_articles['Country']:
        count = articles.count(country)

        country_counts.setdefault(country, 0)
        country_counts[country] += count
country_counts_df = pd.DataFrame(list(country_counts.items()), columns=['Country', 'Count'])


print(country_counts_df)
# Out:
#     Country  Count
# 0  CountryA      1
# 1  CountryB      2
# 2  CountryC      1

# %%
plaintext_articles_data = {'Country': ['CountryA', 'CountryB', 'CountryC']}
path_overview2_data = {'source': ['CountryA', 'SourceB', 'SourceC'],
                       'target': ['TargetA', 'TargetB', 'TargetC'],
                       'paths': ['14th_century 15th_century CountryA Pacific',
                                 '16th_century CountryB 17th_century',
                                 'CountryC 18th_century 19th_century']}

plaintext_articles = pd.DataFrame(plaintext_articles_data)
path_overview2 = pd.DataFrame(path_overview2_data)

country_counts = {}

for _, row in path_overview2.iterrows():
    articles = row['paths'].split()
    for country in plaintext_articles['Country']:
      
        if country in articles and country != row['source'] and country != row['target']:
            
            count = articles.count(country)

            # update dict
            country_counts.setdefault(country, 0)
            country_counts[country] += count

country_counts_df = pd.DataFrame(list(country_counts.items()), columns=['Country', 'Count'])

print(country_counts_df)
# Out:
#     Country  Count
# 0  CountryB      1
# 1  CountryC      1

# %%
# Split "paths" in path_overview2
paths_split = path_overview2
country_frequencies = {}  # dict to store frequencies

for country in plaintext_articles['Country']:
    country_appears = paths_split.apply(lambda x: x.str.contains(country, case=False)).any(axis=1)

    country_frequency = country_appears.sum()

    country_frequencies[country] = country_frequency

# new column
plaintext_articles['country_frequency'] = plaintext_articles['Country'].map(country_frequencies)

print(plaintext_articles)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n_/13fsff_n69dbhvzjzcblm40r0000gn/T/ipykernel_24277/3536192018.py in <module>
#       6 for country in plaintext_articles['Country']:
#       7     # Check if the country appears in any part of the paths for each row
# ----> 8     country_appears = paths_split.apply(lambda x: x.str.contains(country, case=False)).any(axis=1)
#       9
#      10     # Count the number of rows where the country appears
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9563             kwargs=kwargs,
#    9564         )
# -> 9565         return op.apply().__finalize__(self, method="apply")
#    9566
#    9567     def applymap(
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     744             return self.apply_raw()
#     745
# --> 746         return self.apply_standard()
#     747
#     748     def agg(self):
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     871
#     872     def apply_standard(self):
# --> 873         results, res_index = self.apply_series_generator()
#     874
#     875         # wrap results
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     887             for i, v in enumerate(series_gen):
#     888                 # ignore SettingWithCopy here in case the user mutates
# --> 889                 results[i] = self.f(v)
#     890                 if isinstance(results[i], ABCSeries):
#     891                     # If we have a view on v, we need to make a copy because
#
# /var/folders/n_/13fsff_n69dbhvzjzcblm40r0000gn/T/ipykernel_24277/3536192018.py in <lambda>(x)
#       6 for country in plaintext_articles['Country']:
#       7     # Check if the country appears in any part of the paths for each row
# ----> 8     country_appears = paths_split.apply(lambda x: x.str.contains(country, case=False)).any(axis=1)
#       9
#      10     # Count the number of rows where the country appears
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     179         from pandas.core.arrays.string_ import StringDtype
#     180
# --> 181         self._inferred_dtype = self._validate(data)
#     182         self._is_categorical = is_categorical_dtype(data.dtype)
#     183         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/opt/miniconda3/envs/adaexam/lib/python3.9/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     233
#     234         if inferred_dtype not in allowed_types:
# --> 235             raise AttributeError("Can only use .str accessor with string values!")
#     236         return inferred_dtype
#     237
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Split "paths" in path_overview2
paths_split = path_overview2['paths'].str.split(';', expand=True)
country_frequencies = {}  # dict to store frequencies

# Iterate for each country
for country in plaintext_articles['Country']:
    # Find rows where that country is neither source nor target
    relevant_rows = path_overview2[(path_overview2['source'] != country) & (path_overview2['target'] != country)]

    # Count frequency of that country_name in those rows

    country_frequency = paths_split.loc[relevant_rows.index].apply(lambda x: x.str.contains(country, case=False)).sum()

    # Store that number
    country_frequencies[country] = country_frequency

# Create a new column plaintext_articles with the frequencies
plaintext_articles['country_frequency'] = plaintext_articles['Country'].map(country_frequencies)

print(plaintext_articles)

# %%
# split "paths" in path_overview
paths_split = path_overview2['paths'].str.split(';', expand=True)
country_frequencies = {} # dic to store frequencies
# iterate for each country
for country in plaintext_articles['Country']:
    # find rows where that country is neither source nor targer
    relevant_rows = path_overview2[(path_overview2['source'] != country) & (path_overview2['target'] != country)]
    #count frequency of that country_name in those rows
    country_frequency = paths_split.loc[relevant_rows.index].apply(lambda x: x.str.contains(country, case=False)).sum().sum()
    #store that number
    country_frequencies[country] = country_frequency

#create new column in p with that number in plaintext_articles
path_overview2['country_frequency'] = path_overview2['source'].map(country_frequencies)

# Print or use the resulting dataframe paths_overview2
print(path_overview2)

# %%
print("Hello")

# %% [markdown]
# ## Third section of research questions
# The focus for the last two research questions is on trying to control for as many confounders as possible that might influence country wise bias.

# %% [markdown]
# ### Sentiment analysis

# %%
# Access to Huging Face NLP program

# Access to Huging Face NLP program

### TODO: Problem with pipeline

# %pip install -q transformers
# !pip3 install emoji==0.6.0
from transformers import pipeline

# !pip3 install torch
# !pip3 install tensorflow
# !pip3 install transformers
# !pip3 install emoji==0.6.0
# from transformers import pipeline

def sentiment_analysis(s, model_link = "finiteautomata/bertweet-base-sentiment-analysis" , bs = 300):
    """
    Args:
    s (str): The article to be analyzed
    model_link = the sentiment analysis model used from huggingface.com (open source).
    If modified, the lines commentet with "depends on model used", might have to be changed
    bs(int): The length of each part, aka batch_size. For the default model, the max is 300 token
    Returns:
    aggregated_df (pd.Dataframe): A Dataframe containing the sentiment analysis summary
    sentiment (string): 
    """
    input_size = len(s)

   
    # Initialize chosen model for sentiment analysis
    specific_model = pipeline(model= model_link)

    return_df = pd.DataFrame()
    parts = [s[i:i+bs] for i in range(0, input_size, bs)]

    for part in parts:
        output = specific_model(part)
        new_row = pd.DataFrame.from_dict(output) # depends on model used
        return_df = pd.concat([new_row, return_df.loc[:]]).reset_index(drop=True)
    
    aggregated_df = return_df.groupby('label')['score'].agg(['sum', 'count'])

    sentiment = aggregated_df['sum'].idxmax()
    
    return aggregated_df, sentiment
# Out:
# Requirement already satisfied: transformers in c:\users\timar\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\timar\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: boto3 in c:\users\timar\anaconda3\lib\site-packages (from transformers) (1.24.28)
# Requirement already satisfied: requests in c:\users\timar\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\timar\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\timar\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: sentencepiece in c:\users\timar\anaconda3\lib\site-packages (from transformers) (0.1.99)
# Requirement already satisfied: sacremoses in c:\users\timar\anaconda3\lib\site-packages (from transformers) (0.0.43)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\timar\anaconda3\lib\site-packages (from boto3->transformers) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\timar\anaconda3\lib\site-packages (from boto3->transformers) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\timar\anaconda3\lib\site-packages (from boto3->transformers) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\timar\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\timar\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\timar\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timar\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: six in c:\users\timar\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\timar\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: joblib in c:\users\timar\anaconda3\lib\site-packages (from sacremoses->transformers) (1.2.0)
# Requirement already satisfied: colorama in c:\users\timar\anaconda3\lib\site-packages (from tqdm->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\timar\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3->transformers) (2.8.2)
# Requirement already satisfied: emoji==0.6.0 in c:\users\timar\anaconda3\lib\site-packages (0.6.0)
# WARNING:tensorflow:From c:\Users\timar\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\timar\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\timar\OneDrive\Dokumente\Studium\MA1\ADA\Projects\ProjectGitHub\ada-2023-project-jellyfish401\p2.ipynb Cell 39 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a> get_ipython().system('pip3 install transformers')
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a> get_ipython().system('pip3 install emoji==0.6.0')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a> from transformers import pipeline
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a> def sentiment_analysis(s, model_link = "finiteautomata/bertweet-base-sentiment-analysis" , bs = 300):
#      <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a>     """
#      <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a>     Args:
#      <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a>     s (str): The article to be analyzed
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=17'>18</a>     sentiment (string):
#      <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X53sZmlsZQ%3D%3D?line=18'>19</a>     """
#
# ImportError: cannot import name 'pipeline' from 'transformers' (c:\Users\timar\anaconda3\Lib\site-packages\transformers\__init__.py)

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 2.1.1
# Summary: State-of-the-art Natural Language Processing for TensorFlow 2.0 and PyTorch
# Home-page: https://github.com/huggingface/transformers
# Author: Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Google AI Language Team Authors, Open AI team Authors, Facebook AI Authors, Carnegie Mellon University Authors
# Author-email: thomas@huggingface.co
# License: Apache
# Location: C:\Users\timar\anaconda3\Lib\site-packages
# Requires: boto3, numpy, regex, requests, sacremoses, sentencepiece, tqdm
# Required-by:

# %%
from emoji import emojize

# %% [markdown]
# #### Example of sentiment analysis

# %%
# Retrieve the article content of the country
country = 'Switzerland'
content = plaintext_articles.loc[plaintext_articles['Country'] == country, 'Article content'].iloc[0]

summary_df, majority_class = sentiment_analysis(content)

print("Sentiment: " ,majority_class)
summary_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\timar\OneDrive\Dokumente\Studium\MA1\ADA\Projects\ProjectGitHub\ada-2023-project-jellyfish401\p2.ipynb Cell 43 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> country = 'Switzerland'
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> content = plaintext_articles.loc[plaintext_articles['Country'] == country, 'Article content'].iloc[0]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a> summary_df, majority_class = sentiment_analysis(content)
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a> print("Sentiment: " ,majority_class)
#       <a href='vscode-notebook-cell:/c%3A/Users/timar/OneDrive/Dokumente/Studium/MA1/ADA/Projects/ProjectGitHub/ada-2023-project-jellyfish401/p2.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a> summary_df.head(3)
#
# NameError: name 'sentiment_analysis' is not defined

# %% [markdown]
# # Analysis of Bias in the Wikispeedia Dataset and Player Pathways
#
# ### Metrics for Comparison
# We calculate various metrics (referred to as 'Vs') for each country (denoted as 'C') in the Wikispeedia dataset:
#
# * Length of the Wikipedia article for country C
# * Sentiment analysis of the Wikipedia article for country C
# * Number of hyperlinks in other articles pointing to the article about country C
# * Number of hyperlinks in the article about country C pointing to other articles
# * Proportion of completed and uncompleted pathways where country C was the target
# * Length of pathways targeting country C
# * Frequency of article C's involvement in pathways where it was neither the start nor the target
#
# ### Analyzing Vs to Detect Representation Bias
# Given the extensive scope of countries (over 200), we categorize them by region/continent and economic development, utilizing the UN datasets mentioned in the README.
#
# Correlations between the above metrics for country C and its regional or economic attributes do not inherently indicate causality or bias. To assess whether the Wikispeedia dataset (encompassing hyperlink structure and article content) exhibits bias, we need to control for potential confounding factors.
#
# To achieve this, we will develop a predictive model using multiple linear regression that accounts for confounders such as population size, economic strength, and whether English is an official language in country C (considering the use of the English Wikipedia). By comparing the model's predicted values against the actual Vs, we can determine the presence and extent of representation bias.
#
# ### Assessing Player Bias
# After evaluating representation bias in the Wikispeedia framework, we will reexamine the pathways chosen by players. This step aims to discern whether players merely reflect the dataset's bias or introduce additional biases. We will adopt a similar methodology as above for this analysis.
#
# In conclusion, through the application of Natural Language Processing for sentiment analysis and comprehensive statistical controls, our objective is to uncover any latent biases in article representation and player interactions within the Wikispeedia dataset.
